# %%
# !pip install datasets  # si pas déjà installé

from datasets import load_dataset

# Chargement une fois (internet requis ici seulement)
dataset = load_dataset("Estwld/empathetic_dialogues_llm")

# Sauvegarde locale (dans /content/ du Colab)
dataset.save_to_disk("/content/empathetic_dialogues_local")

print("✅ Dataset téléchargé et sauvegardé localement !")
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/5.22M [00:00<?, ?B/s]
# data/valid-00000-of-00001.parquet:   0%|          | 0.00/806k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/19533 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/2770 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2547 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/19533 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2770 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2547 [00:00<?, ? examples/s]
# ✅ Dataset téléchargé et sauvegardé localement !

# %%
# ================================================
# CHATBOT ÉMOTIONNEL COMPLET - Version Finale Colab
# Dataset local + Fine-tuning + Rapport + Interface Gradio
# ================================================

# 1. Installation des dépendances
# !pip install -q transformers datasets torch gradio huggingface_hub accelerate matplotlib

# 2. Imports
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer
from datasets import load_from_disk
import gradio as gr
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime

# %%
# 3. Configuration
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"🖥️ Device détecté : {device}")
# Out:
# 🖥️ Device détecté : cuda

# %%
# 4. Chargement du dataset LOCAL (celui que tu as sauvegardé)
print("\n📚 Chargement du dataset local...")
dataset = load_from_disk("/content/empathetic_dialogues_local")

# Splits
train_raw = dataset["train"].select(range(12000))           # 12k pour entraînement
valid_raw = dataset["valid"].select(range(1000))       # validation
test_raw  = dataset["valid"].select(range(1000, 1500))  # 500 pour test (comme dans ton code original)

print(f"✅ Dataset chargé :")
print(f"   - Train: {len(train_raw)} exemples")
print(f"   - Valid: {len(valid_raw)} exemples")
print(f"   - Test : {len(test_raw)} exemples")
emotions = sorted(list(set(train_raw["emotion"])))
print(f"   - Émotions uniques: {len(emotions)}")
# Out:
# 📚 Chargement du dataset local...
# ✅ Dataset chargé :
#    - Train: 12000 exemples
#    - Valid: 1000 exemples
#    - Test : 500 exemples
#    - Émotions uniques: 32

# %%
print("Exemple du dataset :")
print(dataset["train"][0])
print("\nClés disponibles :", dataset["train"][0].keys())
# Out:
# Exemple du dataset :
# {'conv_id': 'hit:0_conv:1', 'situation': 'I remember going to the fireworks with my best friend. There was a lot of people, but it only felt like us in the world.', 'emotion': 'sentimental', 'conversations': [{'content': 'I remember going to see the fireworks with my best friend. It was the first time we ever spent time alone together. Although there was a lot of people, we felt like the only people in the world.', 'role': 'user'}, {'content': 'Was this a friend you were in love with, or just a best friend?', 'role': 'assistant'}, {'content': 'This was a best friend. I miss her.', 'role': 'user'}, {'content': 'Where has she gone?', 'role': 'assistant'}, {'content': 'We no longer talk.', 'role': 'user'}, {'content': 'Oh was this something that happened because of an argument?', 'role': 'assistant'}]}
#
# Clés disponibles : dict_keys(['conv_id', 'situation', 'emotion', 'conversations'])

# %%
# Cellule 5 : Initialisation du modèle (exécute ça D'ABORD)
model_name = "microsoft/DialoGPT-small"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token  # Très important

model = AutoModelForCausalLM.from_pretrained(model_name)
model.to(device)

print("✅ Tokenizer et modèle chargés avec succès !")
# Out:
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/641 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/351M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ✅ Tokenizer et modèle chargés avec succès !

# %%
# 6. Extraction des paires + tokenisation (corrigé et optimisé)
print("\n🔄 Extraction des paires et tokenisation en cours...")

def create_training_example(emotion, user_msg, assistant_msg):
    """Crée un exemple tokenisé avec préfixe émotionnel"""
    text = f"[{emotion.upper()}] User: {user_msg} {tokenizer.eos_token} Bot: {assistant_msg} {tokenizer.eos_token}"

    encoding = tokenizer(
        text,
        truncation=True,
        max_length=128,
        padding="max_length",
        return_tensors="pt"
    )

    return {
        "input_ids": encoding["input_ids"].flatten(),
        "attention_mask": encoding["attention_mask"].flatten(),
        "labels": encoding["input_ids"].flatten().clone()
    }

# Extraction des paires
train_encodings = []
valid_encodings = []
test_encodings  = []

for split_name, split_data, encodings_list in [
    ("train", train_raw, train_encodings),
    ("valid", valid_raw, valid_encodings),
    ("test",  test_raw,  test_encodings)
]:
    print(f"   Traitement {split_name}...")
    count = 0
    for example in split_data:
        emotion = example["emotion"]
        conversations = example["conversations"]

        for i in range(len(conversations) - 1):
            if (conversations[i]['role'] == 'user' and
                conversations[i+1]['role'] == 'assistant'):
                user_msg = conversations[i]['content']
                assistant_msg = conversations[i+1]['content']

                encodings_list.append(
                    create_training_example(emotion, user_msg, assistant_msg)
                )
                count += 1

    print(f"      → {count} paires extraites pour {split_name}")

print(f"\n✅ Tokenisation terminée !")
print(f"   Train : {len(train_encodings)} exemples")
print(f"   Valid : {len(valid_encodings)} exemples")
print(f"   Test  : {len(test_encodings)} exemples")

# Dataset PyTorch
class EmotionDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {k: v for k, v in self.encodings[idx].items()}

    def __len__(self):
        return len(self.encodings)

train_dataset = EmotionDataset(train_encodings)
valid_dataset = EmotionDataset(valid_encodings)
test_dataset  = EmotionDataset(test_encodings)
# Out:
# 🔄 Extraction des paires et tokenisation en cours...
#    Traitement train...
#       → 24653 paires extraites pour train
#    Traitement valid...
#       → 2093 paires extraites pour valid
#    Traitement test...
#       → 1025 paires extraites pour test
#
# ✅ Tokenisation terminée !
#    Train : 24653 exemples
#    Valid : 2093 exemples
#    Test  : 1025 exemples

# %%
# 7. Paramètres d'entraînement (corrigés pour versions récentes de transformers)
training_args = TrainingArguments(
    output_dir="./results",
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=4,        # Batch effectif = 16
    learning_rate=5e-5,
    warmup_steps=100,
    weight_decay=0.01,
    logging_steps=50,
    eval_strategy="steps",               # ← Changé : evaluation_strategy → eval_strategy
    eval_steps=300,
    save_strategy="steps",               # Optionnel mais recommandé pour cohérence
    save_steps=600,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    report_to="none",
    fp16=(device == "cuda"),             # Accélération GPU
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
)

print("\n🚀 Début du fine-tuning...")
print("⏱️ Durée estimée : 45-90 minutes sur GPU T4 gratuit")

trainer.train()
# Out:
# 🚀 Début du fine-tuning...
# ⏱️ Durée estimée : 45-90 minutes sur GPU T4 gratuit
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='4623' max='4623' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4623/4623 31:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>0.912000</td>
#       <td>0.906255</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.882700</td>
#       <td>0.879377</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.829000</td>
#       <td>0.871526</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.812700</td>
#       <td>0.864477</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.841300</td>
#       <td>0.860396</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.812900</td>
#       <td>0.861085</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.797600</td>
#       <td>0.857111</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.787700</td>
#       <td>0.855332</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.783100</td>
#       <td>0.854430</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.808200</td>
#       <td>0.852588</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.744300</td>
#       <td>0.854306</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.756400</td>
#       <td>0.854690</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.760100</td>
#       <td>0.852951</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.736800</td>
#       <td>0.852396</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.753500</td>
#       <td>0.852248</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['lm_head.weight'].
# TrainOutput(global_step=4623, training_loss=0.8506183434481644, metrics={'train_runtime': 1907.1527, 'train_samples_per_second': 38.78, 'train_steps_per_second': 2.424, 'total_flos': 4831224348672000.0, 'train_loss': 0.8506183434481644, 'epoch': 3.0})

# %%
# 8. Sauvegarde finale
save_path = "./emotion_chatbot_final"
trainer.save_model(save_path)
tokenizer.save_pretrained(save_path)
print(f"💾 Modèle final sauvegardé dans {save_path}")
# Out:
# 💾 Modèle final sauvegardé dans ./emotion_chatbot_final

# %%
# 9. Calcul de la perplexité sur le set de test
print("\n📊 Calcul de la perplexité sur le set de test...")
test_results = trainer.evaluate(test_dataset)
final_perplexity = np.exp(test_results["eval_loss"])
print(f"✅ Perplexité finale : {final_perplexity:.2f}")
# Out:
# 📊 Calcul de la perplexité sur le set de test...
#     <div>
#
#       <progress value='257' max='257' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [257/257 00:06]
#     </div>
# ✅ Perplexité finale : 2.25

# %%
# 10. Génération d'exemples qualitatifs
def generate_response(prompt, emotion="joyful"):
    input_text = f"[{emotion.upper()}] User: {prompt} {tokenizer.eos_token} Bot:"
    inputs = tokenizer(input_text, return_tensors="pt").to(device)
    outputs = model.generate(**inputs, max_new_tokens=80, temperature=0.9, do_sample=True, pad_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response.split("Bot:")[-1].strip()

test_prompts = [
    "Je viens de réussir mon examen !",
    "Je me sens triste aujourd'hui...",
    "Je suis vraiment en colère contre mon collègue.",
    "Wow, je n'arrive pas à y croire !"
]
qualitative_examples = ""
for i, (prompt, emotion) in enumerate(zip(test_prompts, ["joyful", "sad", "angry", "surprised"])):
    response = generate_response(prompt, emotion)
    qualitative_examples += f"- [{emotion.upper()}] {prompt} → {response}\n"

# %%
# 11. Classe ReportGenerator (comme dans ton code original)
class ReportGenerator:
    def __init__(self, output_dir="./report"):
        self.output_dir = output_dir
        os.makedirs(output_dir, exist_ok=True)

    def plot_training_curves(self, train_loss, eval_loss, perplexity):
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))

        axes[0].plot(train_loss, label='Train Loss', linewidth=2)
        if eval_loss:
            axes[0].plot(eval_loss, label='Eval Loss', linewidth=2)
        axes[0].set_title('Training and Evaluation Loss')
        axes[0].set_xlabel('Steps')
        axes[0].legend()
        axes[0].grid(True, alpha=0.3)

        if perplexity:
            axes[1].plot(perplexity, color='green', linewidth=2)
            axes[1].set_title('Model Perplexity Over Time')
            axes[1].set_xlabel('Evaluation Steps')
            axes[1].grid(True, alpha=0.3)

        plt.tight_layout()
        plt.savefig(f"{self.output_dir}/training_curves.png", dpi=300)
        print(f"📊 Graphiques sauvegardés: {self.output_dir}/training_curves.png")
        plt.close()

    def generate_markdown_report(self, config):
        report = f"""# Rapport de Projet - Deep Learning
## Génération de Texte Conversationnel Contrôlée par Émotions

**Date:** {datetime.now().strftime('%Y-%m-%d %H:%M')}

---

## 1. Introduction

Système de génération conversationnelle avec contrôle émotionnel via préfixe, fine-tuné sur EmpatheticDialogues.

## 2. Méthodologie

### 2.1 Dataset
- Taille train: {config['train_size']}
- Taille validation: {config['valid_size']}
- Taille test: {config['test_size']}
- Nombre d'émotions: {config['n_emotions']}

### 2.2 Modèle
- Architecture: DialoGPT-small
- Paramètres: {config['n_params']}M
- Device: {config['device']}

### 2.3 Hyperparamètres
- Epochs: 3
- Learning rate: 5e-5
- Batch effectif: 16 (4 + accumulation 4)

## 3. Résultats

### 3.1 Métriques
- Loss finale: {config['final_loss']:.4f}
- Perplexité: {config['perplexity']:.2f}

### 3.2 Courbes
![Training Curves](training_curves.png)

## 4. Exemples Qualitatifs

{config['qualitative_examples']}

## 5. Conclusion & Perspectives

Le contrôle émotionnel par préfixe fonctionne bien. Perspectives : LoRA, plus de données, modèles plus grands.

---
"""
        with open(f"{self.output_dir}/rapport.md", 'w', encoding='utf-8') as f:
            f.write(report)
        print(f"📄 Rapport généré: {self.output_dir}/rapport.md")

# %%
# Génération du rapport
report_gen = ReportGenerator()

# Extraction des losses du log_history du trainer
train_loss = []
eval_loss = []

for log in trainer.state.log_history:
    if 'loss' in log: # Training loss
        train_loss.append(log['loss'])
    if 'eval_loss' in log: # Evaluation loss
        eval_loss.append(log['eval_loss'])

# La perplexité est déjà calculée comme final_perplexity
perplexity = [final_perplexity] # La fonction plot_training_curves attend une liste ou un array

report_gen.plot_training_curves(train_loss, eval_loss, perplexity)

config = {
    'train_size': len(train_raw),
    'valid_size': len(valid_raw),
    'test_size': len(test_raw),
    'n_emotions': len(emotions),
    'n_params': f"{sum(p.numel() for p in model.parameters())/1e6:.1f}",
    'device': device,
    'final_loss': train_loss[-1] if train_loss else 'N/A',
    'perplexity': final_perplexity,
    'qualitative_examples': qualitative_examples
}

report_gen.generate_markdown_report(config)
# Out:
# 📊 Graphiques sauvegardés: ./report/training_curves.png
# 📄 Rapport généré: ./report/rapport.md

# %%
# 12. Interface Gradio finale (corrigée : bouton Envoyer + Entrée fonctionne)
print("\n🤗 Lancement de l'interface de test...")

def chat(message, emotion, history=[]):
    if not message.strip():
        return history, history  # Évite d'envoyer des messages vides

    response = generate_response(message, emotion)
    history.append((message, response))
    return history, history

with gr.Blocks(theme=gr.themes.Soft()) as demo:
    gr.Markdown("# 🤖 Chatbot Émotionnel Contrôlé")
    gr.Markdown("Fine-tuné sur le vrai **EmpatheticDialogues** • 32 émotions réelles")

    chatbot = gr.Chatbot(height=600)

    with gr.Row():
        msg = gr.Textbox(
            label="Ton message",
            placeholder="Écris ton message ici et appuie sur Entrée ⏎",
            lines=3,
            scale=4,
            submit_btn="Envoyer"  # ← Ajoute le bouton visible "Envoyer"
        )
        emotion_dd = gr.Dropdown(
            choices=emotions,
            value="joyful",
            label="Émotion du contexte",
            scale=1
        )

    clear = gr.Button("🗑️ Effacer la conversation")

    # Envoi avec Entrée ou clic sur le bouton
    msg.submit(chat, [msg, emotion_dd, chatbot], [chatbot, chatbot])

    # Bouton Effacer
    clear.click(lambda: None, None, chatbot, queue=False)

print("🔗 Interface prête ! Clique sur le lien bleu ci-dessous 👇")
demo.launch(share=True)
# Out:
# 🤗 Lancement de l'interface de test...
# /tmp/ipython-input-3053959445.py:12: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft()) as demo:
# /tmp/ipython-input-3053959445.py:16: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=600)
# /tmp/ipython-input-3053959445.py:16: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=600)
# 🔗 Interface prête ! Clique sur le lien bleu ci-dessous 👇
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f3ded438d7aad7be67.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f3ded438d7aad7be67.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Zip automatique de TOUT ce qui existe dans /content/ (sans warnings inutiles)
# !zip -r chatbot_complet.zip /content/*

# Téléchargement direct sur ton PC
from google.colab import files
files.download('chatbot_complet.zip')
# Out:
#   adding: content/DL_Text-Synthesizing/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/special_tokens_map.json (deflated 74%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/tokenizer_config.json (deflated 56%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/training_args.bin (deflated 53%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/config.json (deflated 51%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/merges.txt (deflated 53%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/chat_template.jinja (deflated 22%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/vocab.json (deflated 59%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/model.safetensors (deflated 7%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/tokenizer.json (deflated 82%)
#   adding: content/DL_Text-Synthesizing/emotion_chatbot_final/generation_config.json (deflated 24%)
#   adding: content/DL_Text-Synthesizing/.git/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/update.sample (deflated 68%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/DL_Text-Synthesizing/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/DL_Text-Synthesizing/.git/branches/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/config (deflated 25%)
#   adding: content/DL_Text-Synthesizing/.git/COMMIT_EDITMSG (deflated 8%)
#   adding: content/DL_Text-Synthesizing/.git/refs/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/refs/heads/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/refs/heads/main (deflated 2%)
#   adding: content/DL_Text-Synthesizing/.git/refs/tags/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/info/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/info/exclude (deflated 28%)
#   adding: content/DL_Text-Synthesizing/.git/index (deflated 45%)
#   adding: content/DL_Text-Synthesizing/.git/description (deflated 14%)
#   adding: content/DL_Text-Synthesizing/.git/logs/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/logs/refs/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/logs/refs/heads/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/logs/refs/heads/main (deflated 25%)
#   adding: content/DL_Text-Synthesizing/.git/logs/HEAD (deflated 25%)
#   adding: content/DL_Text-Synthesizing/.git/objects/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/98/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/98/fa62f1c4abf3ac3c5e6f5092c092a3c3273ca0 (deflated 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/8f/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/8f/ec380b349b2ee51f595ad637f1b36b0083f663 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/46/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/46/0710da823829a1b372155fd4c233838dc38547 (deflated 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/57/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/57/265dc25e5e0af0607a8966ba32945b66b52209 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/0e/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/0e/2a68b31de533968b3517619ec125a20b9a944e (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/ff/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/ff/00467fa5e2a22ed845e31d94f5950d3d0f72dd (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/d2/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/d2/4aa6d3be5d460f1b10c757897a2622650c7615 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/c9/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/c9/719a266ef1a82cd1d46f2496b0a53b41d5ad88 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/22/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/22/6b0752cac7789c48f0cb3ec53eda48b7be36cc (deflated 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/34/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/34/c4b9167cd20f22408941f6030938e416b9aaf1 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/b2/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/b2/d2dbc845800c78fe98656af927d831ab4ff7b7 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/eb/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/eb/16a53814c71fdc72dff2b85320ea2d3b7c4950 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/8a/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/8a/67d18812bcdec6becfec8f79b61006473d43a3 (deflated 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/info/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/a6/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/a6/08adcd75541c58eb8ba95658a91ed798d5d5a4 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/pack/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/84/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/84/ef7fb594b5c0979e48bdeddb60a0adef33df0b (deflated 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/81/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/objects/81/ab1b72b689f11fe64aa0c70cc6fbab768db7c8 (stored 0%)
#   adding: content/DL_Text-Synthesizing/.git/HEAD (stored 0%)
#   adding: content/DL_Text-Synthesizing/projet_chatbot_emotionnel_complet.zip (stored 0%)
#   adding: content/DL_Text-Synthesizing/mon_projet_chatbot_complet.zip (stored 0%)
#   adding: content/DL_Text-Synthesizing/report/ (stored 0%)
#   adding: content/DL_Text-Synthesizing/report/rapport.md (deflated 38%)
#   adding: content/DL_Text-Synthesizing/report/training_curves.png (deflated 25%)
#   adding: content/emotion_chatbot_final/ (stored 0%)
#   adding: content/emotion_chatbot_final/special_tokens_map.json (deflated 74%)
#   adding: content/emotion_chatbot_final/tokenizer_config.json (deflated 56%)
#   adding: content/emotion_chatbot_final/training_args.bin (deflated 53%)
#   adding: content/emotion_chatbot_final/config.json (deflated 51%)
#   adding: content/emotion_chatbot_final/merges.txt (deflated 53%)
#   adding: content/emotion_chatbot_final/chat_template.jinja (deflated 22%)
#   adding: content/emotion_chatbot_final/vocab.json (deflated 59%)
#   adding: content/emotion_chatbot_final/model.safetensors (deflated 7%)
#   adding: content/emotion_chatbot_final/tokenizer.json (deflated 82%)
#   adding: content/emotion_chatbot_final/generation_config.json (deflated 24%)
#   adding: content/empathetic_dialogues_local/ (stored 0%)
#   adding: content/empathetic_dialogues_local/train/ (stored 0%)
#   adding: content/empathetic_dialogues_local/train/data-00000-of-00001.arrow (deflated 63%)
#   adding: content/empathetic_dialogues_local/train/dataset_info.json (deflated 73%)
#   adding: content/empathetic_dialogues_local/train/state.json (deflated 38%)
#   adding: content/empathetic_dialogues_local/valid/ (stored 0%)
#   adding: content/empathetic_dialogues_local/valid/data-00000-of-00001.arrow (deflated 63%)
#   adding: content/empathetic_dialogues_local/valid/dataset_info.json (deflated 73%)
#   adding: content/empathetic_dialogues_local/valid/state.json (deflated 37%)
#   adding: content/empathetic_dialogues_local/dataset_dict.json (deflated 3%)
#   adding: content/empathetic_dialogues_local/test/ (stored 0%)
#   adding: content/empathetic_dialogues_local/test/data-00000-of-00001.arrow (deflated 63%)
#   adding: content/empathetic_dialogues_local/test/dataset_info.json (deflated 73%)
#   adding: content/empathetic_dialogues_local/test/state.json (deflated 38%)
#   adding: content/report/ (stored 0%)
#   adding: content/report/rapport.md (deflated 38%)
#   adding: content/report/training_curves.png (deflated 25%)
#   adding: content/results/ (stored 0%)
#   adding: content/results/checkpoint-4623/ (stored 0%)
#   adding: content/results/checkpoint-4623/training_args.bin (deflated 53%)
#   adding: content/results/checkpoint-4623/config.json (deflated 51%)
#   adding: content/results/checkpoint-4623/scheduler.pt (deflated 62%)
#   adding: content/results/checkpoint-4623/optimizer.pt (deflated 8%)
#   adding: content/results/checkpoint-4623/trainer_state.json (deflated 77%)
#   adding: content/results/checkpoint-4623/scaler.pt (deflated 64%)
#   adding: content/results/checkpoint-4623/model.safetensors (deflated 7%)
#   adding: content/results/checkpoint-4623/rng_state.pth (deflated 26%)
#   adding: content/results/checkpoint-4623/generation_config.json (deflated 24%)
#   adding: content/results/checkpoint-4200/ (stored 0%)
#   adding: content/results/checkpoint-4200/training_args.bin (deflated 53%)
#   adding: content/results/checkpoint-4200/config.json (deflated 51%)
#   adding: content/results/checkpoint-4200/scheduler.pt (deflated 61%)
#   adding: content/results/checkpoint-4200/optimizer.pt (deflated 8%)
#   adding: content/results/checkpoint-4200/trainer_state.json (deflated 77%)
#   adding: content/results/checkpoint-4200/scaler.pt (deflated 64%)
#   adding: content/results/checkpoint-4200/model.safetensors (deflated 7%)
#   adding: content/results/checkpoint-4200/rng_state.pth (deflated 26%)
#   adding: content/results/checkpoint-4200/generation_config.json (deflated 24%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 39%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/Text-Synthesizing/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/hooks/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/hooks/update.sample (deflated 68%)
#   adding: content/Text-Synthesizing/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/Text-Synthesizing/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/Text-Synthesizing/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/Text-Synthesizing/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/Text-Synthesizing/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/Text-Synthesizing/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/Text-Synthesizing/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/Text-Synthesizing/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/Text-Synthesizing/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/Text-Synthesizing/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/Text-Synthesizing/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/Text-Synthesizing/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/Text-Synthesizing/.git/branches/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/config (deflated 31%)
#   adding: content/Text-Synthesizing/.git/refs/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/refs/heads/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/refs/heads/main (stored 0%)
#   adding: content/Text-Synthesizing/.git/refs/tags/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/refs/remotes/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/Text-Synthesizing/.git/info/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/info/exclude (deflated 28%)
#   adding: content/Text-Synthesizing/.git/index (deflated 11%)
#   adding: content/Text-Synthesizing/.git/description (deflated 14%)
#   adding: content/Text-Synthesizing/.git/logs/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/logs/refs/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/logs/refs/heads/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/logs/refs/heads/main (deflated 29%)
#   adding: content/Text-Synthesizing/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/logs/refs/remotes/origin/HEAD (deflated 29%)
#   adding: content/Text-Synthesizing/.git/logs/HEAD (deflated 29%)
#   adding: content/Text-Synthesizing/.git/objects/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/objects/info/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/objects/pack/ (stored 0%)
#   adding: content/Text-Synthesizing/.git/objects/pack/pack-bb6e27227a02b5f34d345fb6cd46846c9bf6728f.idx (deflated 87%)
#   adding: content/Text-Synthesizing/.git/objects/pack/pack-bb6e27227a02b5f34d345fb6cd46846c9bf6728f.pack (stored 0%)
#   adding: content/Text-Synthesizing/.git/packed-refs (deflated 10%)
#   adding: content/Text-Synthesizing/.git/HEAD (stored 0%)
#   adding: content/Text-Synthesizing/Untitled1 (1).ipynb (deflated 79%)
